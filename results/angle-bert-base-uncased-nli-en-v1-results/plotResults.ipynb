# %%
# single-pass-ByTitle-ANGLE-LOAD   0.975
import matplotlib.pyplot as plt
import pandas as pd

# 从文本文件中解析数据
data = {
    'threshold': [],
    'RI': [],
    'Precision': [],
    'Recall': [],
    'F-value': [],
    'ARI': [],
}

with open('./ANGLE-LOAD-ByTitle-results/EVAL-single-pass-ByTitle-ANGLE-LOAD_results.txt', 'r') as f:
    for line in f:
        line = line.strip()
        if line.startswith('threshold:'):
            data['threshold'].append(float(line.split()[-1]))
        elif line.startswith(('RI', 'Precision', 'Recall', 'F-value', 'ARI')):
            key, value = line.split(': ')
            data[key].append(float(value))

# 将数据转换为pandas DataFrame
df = pd.DataFrame(data)

# 根据threshold列进行排序
df = df.sort_values(by='threshold')
print(df)

# 绘制图表
plt.figure(figsize=(10, 6))  # 设置图表大小
for column in df.columns:
    if column != 'threshold':
        plt.plot(df['threshold'], df[column], marker='o', label=column)  # 添加点标记

plt.xlabel('Threshold')
plt.ylabel('Score')
plt.title('Metric Scores by Threshold')  # 添加图表标题
plt.legend()
plt.grid(True)  # 添加网格线
plt.tight_layout()  # 自动调整子图参数, 使之填充整个图像区域
plt.show()
# Out:
#     threshold        RI  Precision    Recall   F-value       ARI
# 0       0.900  0.131806   0.013962  0.470588  0.027119 -0.024026
# 1       0.910  0.131806   0.013962  0.470588  0.027119 -0.024026
# 2       0.920  0.188418   0.014937  0.470588  0.028956 -0.021984
# 3       0.930  0.203932   0.013373  0.411765  0.025905 -0.025144
# 4       0.940  0.527328   0.022612  0.411765  0.042870 -0.006170
# 5       0.950  0.764579   0.047530  0.428571  0.085570  0.041205
# 6       0.960  0.977557   0.602740  0.369748  0.458333  0.447545
# 10      0.965  0.979090   0.641026  0.420168  0.507614  0.497405
# 7       0.970  0.986848   0.837209  0.605042  0.702439  0.695892
# 13      0.971  0.986419   0.825581  0.596639  0.692683  0.685923
# 12      0.972  0.987279   0.848837  0.613445  0.712195  0.705863
# 14      0.973  0.985997   0.806818  0.596639  0.685990  0.678994
# 11      0.975  0.987075   0.831461  0.621849  0.711538  0.705068
# ...

# %%
# single-pass-ByBody_results : 0.995   
import matplotlib.pyplot as plt
import pandas as pd

# 从文本文件中解析数据
data = {
    'threshold': [],
    'RI': [],
    'Precision': [],
    'Recall': [],
    'F-value': [],
    'ARI': [],
}

with open('./ANGLE-LOAD-ByBody-results/EVAL-single-pass-ByBody_results.txt', 'r') as f:
    for line in f:
        line = line.strip()
        if line.startswith('threshold:'):
            data['threshold'].append(float(line.split()[-1]))
        elif line.startswith(('RI', 'Precision', 'Recall', 'F-value', 'ARI')):
            key, value = line.split(': ')
            data[key].append(float(value))

# 将数据转换为pandas DataFrame
df = pd.DataFrame(data)

# 根据threshold列进行排序
df = df.sort_values(by='threshold')
print(df)

# 绘制图表
plt.figure(figsize=(10, 6))  # 设置图表大小
for column in df.columns:
    if column != 'threshold':
        plt.plot(df['threshold'], df[column], marker='o', label=column)  # 添加点标记

plt.xlabel('Threshold')
plt.ylabel('Score')
plt.title('Metric Scores by Threshold')  # 添加图表标题
plt.legend()
plt.grid(True)  # 添加网格线
plt.tight_layout()  # 自动调整子图参数, 使之填充整个图像区域
plt.show()
# Out:
#     threshold        RI  Precision    Recall   F-value       ARI
# 2       0.900  0.092264   0.012888  0.453782  0.025064 -0.026255
# 3       0.910  0.092264   0.012888  0.453782  0.025064 -0.026255
# 4       0.920  0.092264   0.012888  0.453782  0.025064 -0.026255
# 5       0.930  0.092264   0.012888  0.453782  0.025064 -0.026255
# 6       0.940  0.092264   0.012888  0.453782  0.025064 -0.026255
# 7       0.950  0.092264   0.012888  0.453782  0.025064 -0.026255
# 8       0.960  0.092264   0.012888  0.453782  0.025064 -0.026255
# 9       0.970  0.964780   0.060000  0.025210  0.035503  0.020602
# 10      0.980  0.965428   0.098039  0.042017  0.058824  0.044076
# 11      0.990  0.967617   0.228070  0.109244  0.147727  0.133305
# 0       0.990  0.967617   0.228070  0.109244  0.147727  0.133305
# 1       0.990  0.967617   0.228070  0.109244  0.147727  0.133305
# 15      0.993  0.981034   0.696203  0.462185  0.555556  0.546270
# ...

# %%
# Transformer-LOAD-ByTitle : 0.98
import matplotlib.pyplot as plt
import pandas as pd

# 从文本文件中解析数据
data = {
    'threshold': [],
    'RI': [],
    'Precision': [],
    'Recall': [],
    'F-value': [],
    'ARI': [],
}

with open('./Transformer-LOAD-ByTitle-results/EVAL-single-pass-ByTitle_results.txt', 'r') as f:
    for line in f:
        line = line.strip()
        if line.startswith('threshold:'):
            data['threshold'].append(float(line.split()[-1]))
        elif line.startswith(('RI', 'Precision', 'Recall', 'F-value', 'ARI')):
            key, value = line.split(': ')
            data[key].append(float(value))

# 将数据转换为pandas DataFrame
df = pd.DataFrame(data)

# 根据threshold列进行排序
df = df.sort_values(by='threshold')
print(df)

# 绘制图表
plt.figure(figsize=(10, 6))  # 设置图表大小
for column in df.columns:
    if column != 'threshold':
        plt.plot(df['threshold'], df[column], marker='o', label=column)  # 添加点标记

plt.xlabel('Threshold')
plt.ylabel('Score')
plt.title('Metric Scores by Threshold')  # 添加图表标题
plt.legend()
plt.grid(True)  # 添加网格线
plt.tight_layout()  # 自动调整子图参数, 使之填充整个图像区域
plt.show()
# Out:
#     threshold        RI  Precision    Recall   F-value       ARI
# 0        0.90  0.131806   0.013962  0.470588  0.027119 -0.024026
# 1        0.91  0.131806   0.013962  0.470588  0.027119 -0.024026
# 2        0.92  0.131806   0.013962  0.470588  0.027119 -0.024026
# 3        0.93  0.167207   0.013034  0.420168  0.025284 -0.025874
# 4        0.94  0.186217   0.013600  0.428571  0.026363 -0.024701
# 5        0.95  0.605962   0.026652  0.403361  0.050000  0.001861
# 6        0.96  0.807343   0.071032  0.537815  0.125490  0.083893
# 7        0.97  0.940846   0.229965  0.554622  0.325123  0.299687
# 8        0.98  0.986437   0.804348  0.621849  0.701422  0.694599
# 9        0.99  0.983878   0.734043  0.579832  0.647887  0.639754
# 10       0.99  0.983240   0.715789  0.571429  0.635514  0.627047
# 11       0.99  0.983878   0.734043  0.579832  0.647887  0.639754
# 12       0.99  0.983240   0.715789  0.571429  0.635514  0.627047
